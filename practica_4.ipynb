# %% [markdown]
# <h4 style="color: white;"><h3><strong>PRÁCTICA 4: Introducción a Bipotenciales</strong></h3></h4>
# <p style="font-style: italic;">Karen Agudelo, Luisa Maria Hernandez</p>

# %% [markdown]
# **Nota** se anexa a la entrega las imágenes correspondientes a las señales registrados durante las horas de clases, de manera que los archivo tiene la siguiente disposición:
#
# •	Anexo_1_pt4: imagen de registro de ECG a partir de código generado en lenguaje Python.
#
#
# •	Anexo_2_pt4: imagen de registro de EMG a partir de código generado en lenguaje Python.
#
# •	Anexo_3_pt4: imagen de registro de ECG a partir de código generado en lenguaje C++.
#
# Se hace la aclaración de que la imagen de anexo 1 no corresponde a los datos usados en el análisis de señal dado que al momento del registro el archivo que contenía la información correspondiente a la imagen se sobre escribió con otro, se tomó un archivo compartido por otro grupo de compañeros de acuerdo a la sugerencia del monitor.
#
#
# ### Punto 5.1

# %% [markdown]
# ![Colorful and White Modern Company History Chronological Presentation.png](<attachment:Colorful and White Modern Company History Chronological Presentation.png>)

# %% [markdown]
# <h5><p><strong>Componentes de un equipo de adquisición<strong><p><h5>

# %% [markdown]
# <p>Un sistema de adquisición de datos puede entenderse como una arquitectura modular compuesta por diferentes subsistemas que trabajan de manera integrada para captar, procesar y presentar información proveniente de un fenómeno físico. Estos sistemas se estructuran en cuatro módulos principales:
# <p>(1) el módulo sensor, encargado de interactuar con el sistema bajo estudio y convertir magnitudes físicas en señales medibles (por ejemplo, voltaje); (2) el módulo de acondicionamiento de señal, que incluye funciones analógicas como amplificación y filtrado, así como funciones digitales como temporización y digitalización; (3) el módulo de salida, que presenta la información en un formato interpretable; y (4) el módulo de control, que permite la retroalimentación y actuación sobre el sistema en configuraciones activas. [1]
# Esta estructura general puede observarse en aplicaciones específicas como los sistemas de adquisición de señales electromiográficas (EMG), donde se implementan etapas equivalentes que incluyen electrodos como sensores, preprocesamiento (preamplificación y filtrado), procesamiento adicional de la señal, conversión analógico-digital, suministro de energía y, en muchos casos, módulos de transmisión inalámbrica. De este modo, los sistemas biomédicos no son más que una adaptación especializada de la arquitectura general de adquisición de datos aplicada a señales fisiológicas.<p> [2]

# %% [markdown]
# ### Punto 5.2

# %% [markdown]
# ![Ivory and Peach Colorful Gradient Problem and Solution Graph.png](<attachment:Ivory and Peach Colorful Gradient Problem and Solution Graph.png>)

# %% [markdown]
# [3]

# %% [markdown]
# <p>Se consideran estáticas la interferencia de la red eléctrica (50/60 Hz), el ruido del sistema de adquisición y el desequilibrio de impedancias; sin embargo, no son completamente constantes, ya que pueden experimentar pequeñas variaciones en amplitud o condiciones de operación. En contraste, las fuentes variantes en el tiempo, como la interferencia electromagnética, la interfaz electrodo-piel, los artefactos de movimiento y la actividad muscular no deseada, dependen de factores dinámicos del entorno y del sujeto, presentando cambios impredecibles en amplitud y frecuencia.<p>

# %% [markdown]
# ### Punto 5.3

# %% [markdown]
# <p>En el registro de biopotenciales de superficie, la capa más externa de la piel, el estrato córneo, desempeña un papel fundamental, ya que constituye la principal contribución a la impedancia total de la piel y domina su comportamiento en el rango de bajas frecuencias (1 Hz a 10 kHz) [4]. Esta característica convierte a la interfaz piel-electrodo en un elemento determinante en la calidad de la señal adquirida.<p>
#
# <p>En este contexto, lograr una interfaz de baja impedancia entre el electrodo y la piel es esencial para garantizar una adecuada transducción de las señales fisiológicas. Una impedancia elevada incrementa el ruido térmico en los electrodos, lo que deteriora la relación señal-ruido (SNR) y afecta directamente la fidelidad de la señal registrada. Como consecuencia, pueden presentarse dificultades en la identificación de eventos fisiológicos relevantes, como la activación muscular en estudios de electromiografía (EMG), o alteraciones morfológicas en señales electrocardiográficas (ECG) que complican su interpretación clínica. Asimismo, una alta impedancia aumenta la susceptibilidad a artefactos de movimiento, lo que puede distorsionar componentes críticos de la señal, como el complejo QRS en el ECG. Adicionalmente, esta condición puede limitar la capacidad de monitorear cambios fisiológicos relacionados con la piel, como los niveles de hidratación, afectando tanto mediciones basadas en sudor como estudios dermatológicos [5].<p>
#
# <p>Finalmente, se ha reportado que las propiedades de la piel, más que las características del electrodo en sí, son las que ejercen mayor influencia sobre la impedancia de la interfaz y su estabilidad a lo largo del tiempo, lo que refuerza la importancia de esta etapa dentro del proceso de adquisición de biopotenciales [5].<p>

# %% [markdown]
# En relación con las estrategias para mejorar el acoplamiento piel-electrodo, uno de los enfoques más explorados ha sido la reducción de la impedancia de contacto. Para ello, algunos estudios han propuesto aumentar el área del electrodo, ya que, desde el punto de vista teórico, una mayor superficie de contacto permite disminuir la impedancia en la interfaz. Sin embargo, esta estrategia presenta limitaciones prácticas, especialmente en el contexto de dispositivos portátiles o miniaturizados, como relojes inteligentes, donde el tamaño del electrodo está restringido y no puede incrementarse indefinidamente [4].
#
# Otra línea de investigación se ha centrado en el desarrollo y selección de nuevos materiales de electrodos, particularmente en el caso de electrodos secos, con el objetivo de mejorar su desempeño frente a los electrodos húmedos tradicionales. El enfoque clásico para evaluar estos materiales ha sido predominantemente empírico, basado en la realización de experimentos sobre piel humana y la comparación cualitativa o cuantitativa con electrodos húmedos, considerados el estándar de referencia. No obstante, este método presenta limitaciones importantes debido a la variabilidad inter e intrasujeto en las propiedades de la piel, lo que dificulta la reproducibilidad y generalización de los resultados. Como complemento, algunos trabajos han empleado modelos de impedancia equivalente de la interfaz electrodo-piel, evidenciando que el incremento del área del electrodo efectivamente reduce la impedancia, aunque sin resolver completamente las limitaciones prácticas asociadas [4].
#
# Más recientemente, se han desarrollado soluciones avanzadas basadas en materiales compuestos y estructuras flexibles, orientadas a mejorar simultáneamente la conductividad eléctrica y la adaptabilidad mecánica del electrodo. Un ejemplo de ello es el uso de electrodos secos adaptables a la piel fabricados a partir de una película de polipirrol (PPy) integrada en un sustrato elastomérico de poliestireno-etileno-butadieno-estireno (SEBS), con nanocables de oro (Au NWs) alineados verticalmente. En este tipo de configuraciones, cada componente cumple una función específica: la película de PPy contribuye a reducir la impedancia de contacto (alcanzando valores del orden de 3 kΩ·cm² a 1 kHz) y a incrementar la capacidad de almacenamiento de carga; los nanocables de oro proporcionan baja resistencia superficial y alta elasticidad mecánica; mientras que el sustrato flexible favorece un contacto íntimo y confortable con la piel. Este tipo de enfoques integrales demuestra que la optimización del acoplamiento piel-electrodo no depende de un único factor, sino de la combinación de propiedades eléctricas y mecánicas que permitan una interfaz más estable y eficiente [6].

# %% [markdown]
# ### Punto 5.4

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import neurokit2 as nk
from ecgdetectors import Detectors

# %%
# 1. Cargar datos
datos = np.loadtxt('datos_ECG.txt')

# Grafica
plt.figure(figsize=(15, 5))
plt.plot(datos, linewidth=0.8) 
plt.title('Señal EMG - Vista Expandida')
plt.xlabel('Muestras')
plt.ylabel('Voltaje (V)')
plt.show()

# %% [markdown]
# #### Punto 5.4.1

# %%
fs = 55  # Frecuencia de muestreo (ajusta este valor según tu sensor, ej: 100, 250, 500)

#Prueba de métodos
# MÉTODO 1: NeuroKit2 
# Limpia la señal y detecta picos
signals, info = nk.ecg_process(datos, sampling_rate=fs)
picos_nk = info['ECG_R_Peaks']

# MÉTODO 2: Py-ECG-Detectors
detectors = Detectors(fs)
picos_det = detectors.hamilton_detector(datos)


plt.figure(figsize=(15, 6))
plt.plot(datos, color='lightgray', label='Señal EKG', alpha=0.8)

# Marcar picos de NeuroKit
plt.scatter(picos_nk, datos[picos_nk], color='red', label='NeuroKit (Pan-Tompkins)', marker='o')

# Marcar picos de Detectors (con un pequeño desfase visual para comparar)
plt.scatter(picos_det, datos[picos_det], color='blue', label='Detectors (Hamilton)', marker='x')

plt.title('Comparación de Detectores de Picos R')
plt.legend()
plt.show()

print(f"Picos detectados por NeuroKit: {len(picos_nk)}")
print(f"Picos detectados por Detectors: {len(picos_det)}")
# Out:
# Picos detectados por NeuroKit: 15
# Picos detectados por Detectors: 16

# %% [markdown]
# **Análisis de detección de picos R**
#
# De acuerdo a la gráfica, se asume que la identificación de los picos R por parte del algoritmo Pan-Tompkins tiene mejor desempeño para este conjunto de datos a comparación del algoritmo Hamilton.
#
# Por su parte, el algoritmo implementado a través de NeuroKit tiene consistencia incluso cuando la amplitud presenta pequeñas variaciones; por su parte, el algoritmo Hamilton muestra un mal rendimiento, ya que las marcas de detección están desplazadas hacia abajo o hacia los lados, imposibilitando la detección de los picos R de la señal, aunque en algunos casos parece detectarlos y en otros identifica ruido o componentes de la onda T como si fueran picos R.
#
# *-->Implicaciones de la frecuencia de muestreo*
#
#  El análisis de los picos R está relacionado con el método de recolección de datos; al usar arduino.inWaiting() combinado con time.sleep(2) en el código de recolección de datos, los mismos no se procesan en tiempo real, sino en bloques o ráfagas. Esto genera retardos o irregularidades donde el tiempo de muestreo no llega a ser perfectamente constante debido a los retardos de procesamiento del sistema operativo o de la comunicación serial.
#
# Para el caso del algoritmo de detección de NeuroKit, se usan filtros digitales internos que ubican el complejo QRS; estos dependen de que se le asigne un valor de frecuencia de muestreo, la cual actuaría como un parámetro de calibración, lo que quiere decir que si el valor ingresado no coincide con el ritmo promedio al que el buffer entregó los datos, los filtros no funcionan cien por ciento bien de acuerdo con la señal, provocando errores en la detección. Teniendo en cuenta las condiciones de recolección de datos, se realizaron pruebas con diferentes frecuencias de muestreo y se determinó que la que mostraba mejores resultados en la detección de los picos para los dos algoritmos es Fs=55Hz.

# %% [markdown]
# #### Punto 5.4.2

# %%
# 3. Detectar picos R usando el método de NeuroKit (el que te funcionó bien)
peaks, info = nk.ecg_peaks(datos, sampling_rate=fs, method="neurokit")

plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams['figure.dpi'] = 100 

# 4. Calcular HRV (Variabilidad de la Frecuencia Cardíaca)
hrv_indices = nk.hrv(peaks, sampling_rate=fs, show=True)


# 5. Mostrar los resultados principales
mean_nn = hrv_indices['HRV_MeanNN'].values[0]
bpm_medio = 60000 / mean_nn

print("--- Índices de HRV detectados ---")
print(f"Intervalo R-R promedio (MeanNN): {mean_nn:.2f} ms")
print(f"Frecuencia Cardíaca Media: {bpm_medio:.2f} BPM") # <--- ESTO es lo que el profe esperará ver
print(f"RMSSD (Actividad Parasimpática): {hrv_indices['HRV_RMSSD'].values[0]:.2f} ms")
print(f"SDNN (Variabilidad Total): {hrv_indices['HRV_SDNN'].values[0]:.2f} ms")

plt.tight_layout(pad=3.0) # pad aumenta el espacio entre los cuadros
plt.show()
# Out:
# c:\Users\Karen\AppData\Local\Programs\Python\Python311\Lib\site-packages\neurokit2\hrv\hrv_nonlinear.py:544: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# c:\Users\Karen\AppData\Local\Programs\Python\Python311\Lib\site-packages\neurokit2\complexity\entropy_multiscale.py:346: RuntimeWarning: invalid value encountered in scalar divide
#   mse = np.trapezoid(mse) / len(mse)
# c:\Users\Karen\AppData\Local\Programs\Python\Python311\Lib\site-packages\neurokit2\complexity\optim_complexity_k.py:134: RuntimeWarning: divide by zero encountered in divide
#   normalization = (n - 1) / (np.floor((n - k_subrange) / k).astype(int) * k)
# ...

# %% [markdown]
# **Análisi de VFC** teniendo en cuenta que la variabilidad de la frecuencia cardíaca mide los cambios sutiles entre latidos, los retrasos mencionados anteriormente implican que las meticas de VFC puedan verse alteradas por el "ruido" temporal que se produce en el sistema de adquisicion al no poder recopilar los datos en tiempo real, además se considera que las pequeñas variaciones detectadas en los intervalos R-R sean producto de la laterncia en la lectura del puerto serial y no exclusivamente de los variabilidad fisiológica del sujeto.

# %% [markdown]
# #### Punto 5.4.3

# %%
from hrvanalysis import get_time_domain_features

# %%
print("Número de picos:", len(peaks))
print(peaks)
# Out:
# Número de picos: 1000
#      ECG_R_Peaks
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 995            0
# 996            0
# 997            0
# 998            0
# 999            0
#
# [1000 rows x 1 columns]

# %%
# Extraer índices reales de picos
peaks_indices = np.where(peaks["ECG_R_Peaks"] == 1)[0]

print("Número de picos reales:", len(peaks_indices))

if len(peaks_indices) < 2:
    print("No hay suficientes picos")
else:
    rr_intervals = np.diff(peaks_indices) * (1000 / fs)

    time_domain_features = get_time_domain_features(rr_intervals)

    print("--- Características del Dominio del Tiempo ---")
    for feature, value in time_domain_features.items():
        print(f"{feature:10}: {value:.2f}")
# Out:
# Número de picos reales: 15
# --- Características del Dominio del Tiempo ---
# mean_nni  : 1214.29
# sdnn      : 77.20
# sdsd      : 66.72
# nni_50    : 5.00
# pnni_50   : 38.46
# nni_20    : 8.00
# pnni_20   : 61.54
# rmssd     : 67.09
# median_nni: 1209.09
# range_nni : 236.36
# cvsd      : 0.06
# cvnni     : 0.06
# mean_hr   : 49.60
# max_hr    : 55.00
# min_hr    : 45.21
# std_hr    : 3.05

# %% [markdown]
# **Investigación función get_time_domain_features**
#
# La función get_time_domain_features de la librería hrvanalysis calcula métricas estadísticas a partir de los intervalos NN (Normal-to-Normal), que son los intervalos RR tras haber filtrado posibles latidos ectópicos o ruido [7].
#
# 1. Mean NNI: es el promedio de los intervalos entre latidos en milisegundos, tiene relación inversa con la frecuencia cardíaca media.
#
# 2. SDNN: es la desviación estándar de los intervalos NN, utilizada para evaluar la variabilidad total del sistema [8].
#
# 3. RMSSD: es el parámetro principal para evaluar la actividad parasimpática (tono vagal) [9].
#
# 4. pNN50/pNN20: representa el porcentaje de intervalos sucesivos que varían más de 50 ms. Valores altos indican una mayor influencia del nervio vago sobre el corazón [8].
#
# 5. Mean HR: frecuencia cardíaca promedio calculada a partir de los intervalos detectados.
#
# **Análisis de resultados obtenidos**
#
# Teniendo en cuenta el valor de la frecuencia cardíaca a partir de la función get_time_domain_features de 49.60 (de aprox 50), se interpreta desde el aspecto fisiológico que el sujeto evaluado puede presentar bradicardia (menos de 60 BPM) o que el sujeto esté en reposo absoluto; por otro lado también se debe considerar que a causa de la corta duración de la toma (se alcanzan a identificar solo 15 picos), este valor es una toma muy breve del estado del sujeto.
#
# Por su parte, el valor SDNN de 77.20 ms se considera saludable en registros de corta duración, indicando que el corazón responde a la modulación autónoma [8]. El Range NNI (236.36 ms) indica que existe una diferencia considerable entre el intervalo más largo y el más corto, lo que confirma una variabilidad activa. El RMSSD (67.09 ms) en adultos jóvenes sanos indica una buena salud vagal, ya que valores mayores a 40-50 ms son positivos [9]. El pNN50 (38.46%) refuerza la idea de que el sistema parasimpático está ejerciendo un control efectivo sobre el ritmo cardíaco.
#
# Se tiene en cuenta que las métricas de HRV suelen requerir registros de al menos 2 a 5 minutos para ser estadísticamente significativas. Al tener solo 15 picos, los resultados son preliminares y muy sensibles a cualquier error [8]. Además, se toma en cuenta que parte del SDNN podría no ser variabilidad cardíaca real, sino variabilidad instrumental provocada por los retrasos del sistema de adquisición [10].

# %% [markdown]
# ### Punto 5.5

# %% [markdown]
# #### Artículos ECG
# **1. Un enfoque de aprendizaje profundo para la detección en tiempo real de la fibrilación auricular**
#
#
# *Tipo de registro:* Se toma en cuenta un registro ambulatorio como un Holter con tiempo de grabación prolongado de mas de 24 horas para poder identificar correctamente el evento arrítmico, las grabaciones extendidas de un Holter introducen una gran cantidad de datos que serán procesador luego por software analítico.
#
#
# *Procesamiento:*
# El procesamiento descrito en el articulo no analiza la señal ECG completa, sino que se enfoca en la variabilidad de la frecuencia cardíaca a través de los intervalos latido a latido.
# 1.	Conversión a RRI: el modelo usa secuencias de RRI reduciendo la carga computacional y resaltando las características principales de FA (irregularidades en la contracción ventricular), posterior a la simplificación la señal se segmenta cada 30 latidos (RRI) con un desplazamiento de 10 latidos entre segmentos. El segmento se clasifica como FA si mas del 50 % de sus latidos son marcados como tales en las bases de datos de referencia.
# 2.	Extracción y clasificación: cuenta con dos tipos de redes para aprovechar tanto la forma de la señal como su contexto temporal:
# •	 Capas convolucionales CNN: dos capaz actúan como filtro digitales aprendidos, los cuales extraen características abstractas y patrones de dependencia temporal directamente de la secuencia de intervalos.
# •	Capa de agrupación (max_Pooling): Reduce la dimensión de los datos a la mitad, quedándose con las características mas relevantes.
# •	Capa LSTM bidireccional:  es la memoria del modelo, al ser bidireccinal, permite que la red entienda el contexto de la señal hacia delante  y hacia atrás en el tiempo.
# 3.	Clasificación y Optimización
# Salida: Una única neurona con función de activación sigmoide entrega la probabilidad de que el segmento de 30 latidos pertenezca a la clase de Fibrilación Auricular. El umbral estándar de decisión es 0.5.
# Entrenamiento: Se utiliza el algoritmo de Descenso de Gradiente Estocástico (SGD) con Impulso Acelerado de Nesterov (NAG) para acelerar la convergencia del modelo y regularización L2 para evitar el sobreajuste (overfitting)[11].
#
#
#
# **2. Diagnóstico de Infarto Agudo de Miocardio (IAM) mediante Telemetría**
#
#
# *Tipo de registro:* en la investigación se uso registro de ECG reales de la base de datos PTB-ECG, el registro captura la actividad eléctrica del corazón desde 15 ángulos simultáneos, con 12 derivaciones estándar y 3 derivación de Frank; la frecuencia de muestreo es de 1000 muestras por segundo (1000Hz)  y una resolución de 0.5uV.
#
# *Procesamiento:*
#
# •	Normalización min -max y filtrado: cada señal fue ajustada a un rango de amplitud entre 0 y  1. Esto con el objetivo de trabajar con sistema de detección que trabaje con valores uniformes sin alterar la morfología de los patrones del complejo QRS-T.
# Con el fin de limpiar la señal se aplico un filtro Butterworth pasa bajas de orden 8. Este filtro se uso para eliminar componentes de ruido de alta frecuencia.
#
# •	Segmentación: la señal se divide en segmentos de 0.65 segundo centrados en el pico R para capturar el complejo completo en cada latido. SA estos segmento se les aplica una eliminación de tendencia lineal mediante regresión de mínimos cuadrado, para estabilizar la señal y eliminar inclinaciones no deseadas, permitiendo que el modelo solo se enfoque en variaciones morfológicas.
#
# •	Hiperparámetros: se realizó búsqueda de hiperparámetros mediante técnica de reducción a la mitad sucesiva, la cual selecciona de forma iterativa las mejores combinaciones de parámetros utilizando recursos limitados hasta hallar el estimador con mayor precisión. Este proceso permitió equilibrar el sesgo y la varianza al validar los modelos en conjuntos de datos independientes, resultando en configuraciones específicas de alta precisión para algoritmos KNN y RF [12].
#
#
# **3. Heart rate variability analysis for sleep apnea detection in ECG**
#
#
# *Tipo de registro:* El estudio utiliza la base de datos pública Apnea-ECG de PhysioNet, que consiste en registros de electrocardiograma de un solo cable obtenidos mediante monitoreo nocturno continuo durante un mínimo de 8 horas. Las señales fueron capturadas de una seleccionada de 18 adultos con sospecha de apnea del sueño, utilizando una frecuencia de muestreo de 100 Hz con una resolución de 16 bits para permitir una evaluación detallada de la variabilidad cardíaca minuto a minuto.
#
#
# *Procesamiento de la Señal*
# El procesamiento comenzó con la aplicación de un filtro de muesca a 50 Hz para suprimir la interferencia de la red eléctrica, seguido de un filtrado de paso alto para corregir la desviación de la línea de base de la señal. La detección de picos R se realizó mediante un algoritmo de umbral basado en el periodograma de Welch para asegurar la precisión en registros largos y ruidosos, permitiendo el cálculo de los intervalos RR para construir las series temporales de variabilidad de la frecuencia cardíaca (VFC). Finalmente, las señales se segmentaron en épocas de un minuto sin superposición, las cuales fueron etiquetadas clínicamente como apnea o no apnea para facilitar un análisis autónomo eficiente y con relevancia diagnóstica [13].

# %% [markdown]
# #### Artículos EMG
#
# **1. Reconocimiento de gestos mediante electromiografía de superficie y aprendizaje profundo para prótesis Mano: estado del arte, desafíos y futuro**
#
#
#
# *Tipo de registro:* Las señales sEMG se recopilan de sensores sEMG, que podrían adoptar dos criterios de adquisición diferentes
#
# •	 sEMG multicanal disperso que utiliza pocos sensores colocados en ubicaciones anatómicas precisas sobre músculos específicos para capturar gestos cotidianos con un bajo costo de hardware
#
# •	 sEMG de alta densidad el cual emplea una matriz bidimensional de electrodos distribuidos densamente para medir la distribución espacial de los potenciales de acción de las unidades motoras.
#
#
# *Procesamiento:*
# El preprocesamiento de la señal sEMG busca mitigar su naturaleza ruidosa y no estacionaria mediante tres fases críticas. Inicialmente, el suavizado emplea la rectificación y el filtrado de paso bajo o media móvil para extraer la potencia de la señal y eliminar interferencias. Luego, la normalización ajusta las amplitudes a una escala porcentual, permitiendo la comparación entre diferentes sujetos y sesiones de forma precisa. Por último, la segmentación identifica las áreas de activación muscular mediante umbrales de energía y utiliza ventanas deslizantes superpuestas de 150 a 250 ms, para garantizar un reconocimiento de gestos con un retraso mínimo.
# El procesamiento y extracción de características en sEMG se divide en dos métodos: la extracción tradicional, que calcula manualmente parámetros en los dominios del tiempo, frecuencia y tiempo-frecuencia (como el valor RMS o coeficientes Wavelet) para identifican patrones de movimiento, y la generación de imágenes sEMG, que transforma las señales de múltiples electrodos en mapas espaciales bidimensionales. Este último enfoque convierte la actividad muscular en píxeles, permitiendo que los modelos de inteligencia artificial identifiquen gestos de forma visual y eficiente, logrando un aprendizaje directo desde la señal cruda [14].
#
#
# **2.Diagnóstico de trastornos de la esclerosis lateral amiotrófica (ELA) basado en análisis de señales de electromiograma (EMG) y selección de características**
#
#
# *Tipo de registro:* La electromiografía de superficie (sEMG) se utiliza para registrar las corrientes eléctricas generadas por la actividad de las fibras musculares. Este tipo de registro es ampliamente utilizado en el diagnóstico clínico de enfermedades como la esclerosis lateral amiotrófica (ALS), donde se analizan las diferencias entre señales EMG saludables y patológicas.
#
# *Procesamiento de la señal*
# Análisis en dominio del tiempo y la frecuencia: el procesamiento de señales EMG inicia con el análisis de sus características en el dominio del tiempo y la frecuencia, lo que permite identificar patrones asociados a la actividad muscular y posibles alteraciones neuromusculares.
# Análisis tiempo-frecuencia: Dado que las señales EMG son no estacionarias, se emplean métodos como la transformada wavelet continua (CWT), que permite analizar cómo varía el contenido espectral a lo largo del tiempo sin perder resolución temporal ni frecuencial. En particular, se utilizan wavelets como Daubechies (db4), debido a su similitud con los potenciales de acción de unidades motoras.
# Análisis de orden superior:Se aplican técnicas como el análisis bispectral, que permiten evaluar la no gaussianidad de la señal y detectar cambios asociados al nivel de contracción muscular o a condiciones patológicas.
# Extracción de características: A partir de los análisis anteriores, se obtienen parámetros relevantes como el valor cuadrático medio (RMS), el logRMS, el centroide de frecuencia y la desviación estándar, los cuales representan cuantitativamente el comportamiento de la señal.
# Clasificación: Finalmente, estas características se utilizan como entrada en algoritmos de clasificación como máquinas de soporte vectorial (SVM), k-vecinos más cercanos (k-NN) y análisis discriminante lineal (LDA), permitiendo diferenciar entre señales EMG saludables y patológicas con alta precisión [15].
#
#
# **3.Análisis de la sinergia muscular en niños con parálisis cerebral**
#
# *Tipo de registro*: en este estudio se empleó electromiografía de superficie (sEMG) para registrar la actividad muscular de las extremidades inferiores durante la marcha. Las señales fueron adquiridas de forma bilateral en ocho músculos de las piernas, mientras los sujetos caminaban a una velocidad cómoda. El registro incluyó tres grupos: niños con parálisis cerebral (PC), adultos y niños con desarrollo típico (grupo control), lo que permitió comparar patrones de activación muscular en condiciones normales y patológicas.
#
# *Procesamiento de la señal*
# Análisis de sinergias musculares: el procesamiento se centró en el análisis de sinergias musculares, que representan patrones coordinados de activación de múltiples músculos. Estas sinergias permiten reducir la complejidad del control motor y facilitan la interpretación del funcionamiento neuromuscular.
#
# Factorización de matrices no negativas (NMF)
# Para extraer las sinergias musculares a partir de las señales EMG, se utilizó un algoritmo de factorización de matrices no negativas (NMF). Este método descompone la señal en un conjunto de componentes básicos (sinergias) y sus respectivos niveles de activación, permitiendo identificar patrones subyacentes de coordinación muscular.
#
# Evaluación de características de las sinergias
# Se analizaron propiedades clave de las sinergias musculares, como:
# -Número de sinergias
# -Estructura de activación
# -Simetría entre extremidades
# Estas características permiten evaluar el grado de organización y madurez del control motor.
#
# Cuantificación mediante modelo SCA
# Se implementó un modelo denominado evaluación integral de sinergias (SCA) para cuantificar la anormalidad en las sinergias musculares. Este índice integra múltiples aspectos (estructura, número y simetría) en una métrica que permite comparar entre sujetos y grupos[16].

# %% [markdown]
# ### Conclusiones
#
# * La interfaz piel-electrodo es la etapa más crítica en el registro de biopotenciales, ya que la alta y variable impedancia del estrato córneo introduce ruido, distorsión y artefactos que afectan directamente la calidad de señales como ECG, EMG y EEG.
#
#
# * Se concluye que el algoritmo de Pan-Tompkins es la herramienta de procesamiento más apta para este sistema de adquisición, ya que permite una identificación precisa de los picos R incluso ante las variaciones de amplitud y el ruido presentes en la señal, superando las limitaciones del algoritmo de Hamilton que tiende a confundir componentes de la onda T con actividad ventricular.
#
# * La frecuencia de muestreo de 55 Hz se establece como el parámetro de calibración óptimo para la detección de eventos para estos datos en especifico. Este valor permite compensar los retrasos intrínsecos de la comunicación serial y el procesamiento por ráfagas de este sistema, garantizando que el algoritmo de Neurokit mantengan una consistencia aceptable para el cálculo de los intervalos entre latidos.
#
# * Aunque los valores de variabilidad de la frecuencia cardíaca como el RMSSD y el SDNN contienen infromación fisiológica relevante, estas métricas deben considerarse como indicadores técnicos de la estabilidad del sistema. Debido a la latencia del puerto serial y la brevedad del registro, una fracción de la variabilidad calculada deriva de la inestabilidad temporal de la captura, lo que condiciona la validez de los resultados a una mejora en la velocidad de transferencia de datos.
#
# * La integración de diferentes aplicaciones demuestra que el diagnóstico automatizado en ECG y EMG depende de la sinergia entre el filtrado robusto y la arquitectura del modelo. En ECG, el enfoque técnico se centra en la variabilidad de intervalos R-R y la morfología del segmento ST mediante redes recurrentes (LSTM) y convolucionales para identificar eventos rítmicos o isquémicos. Por su parte, en EMG, la tendencia es el análisis espaciotemporal mediante HD-sEMG y transformadas Wavelet, tratando la actividad muscular como mapas de datos para el control de prótesis o el diagnóstico de patologías como la ELA.

# %% [markdown]
# ### Referencias

# %% [markdown]
# <p>[1]Todd, M. (2014). Sensor data acquisition systems and architectures. En Elsevier eBooks (pp. 23-56). https://doi.org/10.1533/9780857099136.23<p>
# <p>[2] Palumbo, A., Vizza, P., Calabrese, B., & Ielpo, N. (2021). Biopotential Signal Monitoring Systems in Rehabilitation: A Review. Sensors, 21(21), 7172. https://doi.org/10.3390/s21217172<p>
# <p>[3]Chen, M., Wang, J., Anzai, D., Fischer, G., & Kirchner, J. (2020). Common-Mode Noise Reduction in Noncontact Biopotential Acquisition Circuit Based on Imbalance Cancellation of Electrode-Body Impedance. Sensors, 20(24), 7140. https://doi.org/10.3390/s20247140<p>
# <p>[4] Goyal, K., Borkholder, D. A., & Day, S. W. (2022). Dependence of Skin-Electrode Contact Impedance on Material and Skin Hydration. Sensors, 22(21), 8510. https://doi.org/10.3390/s22218510<p>
# <p>[5] Murphy, B. B., Scheid, B. H., Hendricks, Q., Apollo, N. V., Litt, B., & Vitale, F. (2021). Time Evolution of the Skin–Electrode Interface Impedance under Different Skin Treatments. Sensors, 21(15), 5210. https://doi.org/10.3390/s21155210<p>
# <p>[6]Zhang, H., Shen, Y., Xing, L., Wang, W., Liu, L., Jin, R., He, Z., Wang, Y., Yao, S., Cao, X., Dong, S., & Zhu, B. (2025). Interface Enhancement of skin electrodes with vertical gold Nanowires-based interlocking layers for wearable electrophysiological recording. Chemical Engineering Journal, 508, 160973. https://doi.org/10.1016/j.cej.2025.160973<p>
#
# [7] Champion, R. (2020). HRV Analysis: A Python library for Heart Rate Variability analysis. Zenodo. https://doi.org/10.5281/zenodo.3631414
#
# [8] Task Force of the European Society of Cardiology and the North American Society of Pacing and Electrophysiology. (1996). Heart rate variability: Standards of measurement, physiological interpretation, and clinical use. Circulation, 93(5), 1043–1065
#
# [9] Shaffer, F., & Ginsberg, J. P. (2017). An Overview of Heart Rate Variability Metrics and Norms. Frontiers in Public Health, 5(258).
#
# [10] Lyon, A., Mincholé, A., Martinez, J. P., Laguna, P., & Rodriguez, B. (2017). Computational techniques for ECG analysis and interpretation in light of their limitations. Royal Society Open Science, 4(1), 160511.
#
#
# [11] Hannun, A. Y., Rajpurkar, P., Haghpanahi, M., Tison, G. H., Bourn, C., Turakhia, M. P., & Ng, A. Y. (2019). Cardiologist-level arrhythmia detection and classification in ambulatory electrocardiograms using a deep convolutional neural network. Nature Medicine, 25(1), 65-69. https://www-sciencedirect-com.udea.lookproxy.com/science/article/pii/S0957417418305190
#
#
# [12] Sadr, N., Huvanandana, J., Nguyen, D. T., Kalra, C., Gargiulo, G. D., & McEwan, A. L. (2022). Deep Learning for Detection of Myocardial Infarction Using 12-lead ECG Signals. Sensors, 22(18), 6865. https://pmc.ncbi.nlm.nih.gov/articles/PMC9456488/
#
#
# [13] Al-Angari, H. M., & Kanwisher, N. (2015). Heart rate variability analysis for sleep apnea detection in ECG. Computers in Biology and Medicine, 64, 1-10. https://pmc.ncbi.nlm.nih.gov/articles/PMC12457166/
#
#
# [14] Xiong, D., Zhang, D., Zhao, X., & Zhao, Y. (2021). Deep Learning for sEMG-based Gesture Recognition: A Review. Frontiers in Robotics and AI, 8, 636034. https://pmc.ncbi.nlm.nih.gov/articles/PMC8107289/
#
# [15]Gąsior, J. S., Sacha, J., Jeleń, P. J., Zieliński, J., & Przybylski, J. (2020). Heart rate variability and its dependency on heart rate: Issues and options. Polish Journal of Medical Physics and Engineering, 26(3), 153-173.https://doi.org/10.2478/pjmpe-2020-0018
#
# [16] Makowski, D. (2016). NeuroKit: A Python Toolbox for Statistics and Neurophysiological Signal Processing (EEG, ECG, EDA, Respiration). Journal of Open Source Software, 1(4), 47. https://doi.org/10.21105/joss.00047
